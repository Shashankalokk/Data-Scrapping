# %%
#importing all the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup # library used for web scrapping
import requests #for request
import re # for data cleaning

# %%
url = "https://socialclub.rockstargames.com/"
req = requests.get(url)

# %%
req
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(req.content)

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="no-js" data-agent="python-requests/2.31.0" lang="en-US">\n <head data-template-set="html5-reset">\n  <meta charset="utf-8"/>\n  <meta content="ie=edge" http-equiv="x-ua-compatible"/>\n  <title data-rh="">\n   Rockstar Games\n  </title>\n  <meta content="Rockstar Games" data-rh="" name="title"/>\n  <meta content="Rockstar Games, Rockstar" name="keywords"/>\n  <meta content="" data-rh="" name="description"/>\n  <meta content="" name="google-site-verification"/>\n  <meta content="Rockstar North" name="author"/>\n  <meta content="Rockstar Games 2024. All Rights Reserved." name="copyright"/>\n  <meta content="none" name="msapplication-config"/>\n  <meta content="Rockstar Games" name="DC.title"/>\n  <meta content="Rockstar Games, Rockstar" name="DC.subject"/>\n  <meta content="Rockstar North" name="DC.creator"/>\n  <meta content="on" http-equiv="cleartype"/>\n  <meta content="width=device-width, initial-scale=1" name="viewport"/>\n  <meta content="all" name="robots"/>\n  <meta content="origin" name="referrer"/>\n  <meta content="yes" name="mobile-web-app-capable"/>\n  <!-- Chrome, Firefox OS and Opera -->\n  <meta content="#000000" data-rh="" name="theme-color"/>\n  <!-- Windows Phone -->\n  <meta content="#000000" data-rh="" name="msapplication-navbutton-color"/>\n  <!-- iOS Safari -->\n  <meta content="#000000" data-rh="" name="apple-mobile-web-app-status-bar-style"/>\n  <link href="https://s.rsg.sc/sc/images/react/icons/apple-touch-icon-152x152-precomposed.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>\n  <link href="https://s.rsg.sc/sc/images/react/icons/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>\n  <link href="https://s.rsg.sc/sc/images/react/icons/apple-touch-icon-120x120-precomposed.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>\n  <link href="https://s.rsg.sc/sc/images/react/icons/apple-touch-icon-114x114-precomposed.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>\n  <link href="https://s.rsg.sc/sc/images/react/icons/apple-touch-icon-76x76-precomposed.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>\n  <link href="https://s.rsg.sc/sc/images/react/icons/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>\n  <link href="https://s.rsg.sc/sc/images/react/icons/apple-touch-icon-57x57-precomposed.png" rel="apple-touch-icon-precomposed"/>\n  <link href="https://s.rsg.sc/sc/images/react/icons/apple-touch-icon-precomposed.png" rel="shortcut icon"/>\n  <link href="https://s.rsg.sc/sc/rockstar.ico" rel="shortcut icon"/>\n  <meta content="systemjs-importmap" name="importmap-type"/>\n  <script nonce="CSibrBDULAdYLBej7mDODvrHgo2TXr0dkOrJj0DfxoE=" src="https://media-rockstargames-com.akamaized.net/mfe6/importmaps/92ea64/prod.json" type="rs-importmap">\n  </script>\n  <script data-config=\'{"locales":{"selectedLanguageCookieName":"rockstarweb_lang.prod","reactCulture":"en-US"},"websockets":{"messageDistributionReconnectTime":60,"messageDistributionReconnectCount":3},"baseUrls":{"cloud":"https://prod.cloud.rockstargames.com/","lifeInvader":"https://www.lifeinvader.com","newswireHostName":"https://www.rockstargames.com/","scHostName":"socialclub.rockstargames.com","crewEmblemUrl":"https://prod.cloud.rockstargames.com/crews/sc/{0}/{1}/publish/emblem/emblem_{2}.png","emblemGallery":"https://prod.cloud.rockstargames.com/crews/sc/{0}/{1}/publish/emblems/{2}","defaultCrewEmblemUrl":"https://s.rsg.sc/sc/images/emblems/128x128/rockstar1.png","store":"https://store.rockstargames.com"},"uiLib":{"cdnBaseUrl":"https://s.rsg.sc/sc/","avatarUrl":"https://scapi.rockstargames.com/avatars/get?nickname={nickname}&amp;imageSize={imageSize}","crewEmblemBaseUrl":null,"defaultCrewEmblemUrl":"https://s.rsg.sc/sc/images/emblems/128x128/rockstar1.png","crewEmblemUrl":"https://prod.cloud.rockstargames.com/crews/sc/{0}/{1}/publish/emblem/emblem_{2}.png","muteConsole":false,"rootId":"app-root","allowDebugInfo": ...

# %%
arr = []
Film = []
Year= []
Award= []
Nomination= []
count = 0

for i in soup.findAll('td'):
  i= re.sub('^<td>.*">|<td>|</td>|<.*>',"",str(i))
  if count == 0:
    Film.append(i)
    count+=1
  elif count == 1:
    Year.append(i)
    count+=1
  elif count == 2:
    Award.append(i)
    count+=1
  else:
    count = 0
    Nomination.append(i)

# %%
Year
# Out:
# ['2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019\n',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2006',
#  '2006',
#  '2006',
#  '2006',
#  '2006',
#  '2006',
#  '2006',
#  '2006',
#  '2006',
#  '2006',
#  '2006',
#  '2006',
#  '2006',
#  '2006',
#  '2006',
#  '2006',
#  '2005',
#  '2005',
#  '2005',
#  '2005',
#  '2005',
#  '2005',
#  '2005',
#  '2005',
#  '2005',
#  '2005',
#  '2005',
#  '2005',
#  '2005',
#  '2005',
#  '2005',
#  '2005',
#  '2004',
#  '2004',
#  '2004',
#  '2004',
#  '2004',
#  '2004',
#  '2004',
#  '2004',
#  '2004',
#  '2004',
#  '2004',
#  '2004',
#  '2004',
#  '2004',
#  '2004',
#  '2003',
#  '2003',
#  '2003',
#  '2003',
#  '2003',
#  '2003',
#  '2003',
#  '2003',
#  '2003',
#  '2003',
#  '2003',
#  '2003',
#  '2002',
#  '2002',
#  '2002',
#  '2002',
#  '2002',
#  '2002',
#  '2002',
#  '2002',
#  '2002',
#  '2002',
#  '2002',
#  '2002',
#  '2002',
#  '2002',
#  '2002',
#  '2001',
#  '2001',
#  '2001',
#  '2001',
#  '2001',
#  '2001',
#  '2001',
#  '2001',
#  '2001',
#  '2001',
#  '2001',
#  '2001',
#  '2001',
#  '2001',
#  '2001',
#  '2001',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '1999',
#  '1999',
#  '1999',
#  '1999',
#  '1999',
#  '1999',
#  '1999',
#  '1999',
#  '1999',
#  '1999',
#  '1999',
#  '1999',
#  '1999',
#  '1999',
#  '1998',
#  '1998',
#  '1998',
#  '1998',
#  '1998',
#  '1998',
#  '1998',
#  '1998',
#  '1998',
#  '1998',
#  '1998',
#  '1998',
#  '1997',
#  '1997',
#  '1997',
#  '1997',
#  '1997',
#  '1997',
#  '1997',
#  '1997',
#  '1997',
#  '1997',
#  '1997',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1995',
#  '1995',
#  '1995',
#  '1995',
#  '1995',
#  '1995',
#  '1995',
#  '1995',
#  '1995',
#  '1995',
#  '1995',
#  '1995',
#  '1995',
#  '1995',
#  '1995',
#  '1995',
#  '1995',
#  '1994',
#  '1994',
#  '1994',
#  '1994',
#  '1994',
#  '1994',
#  '1994',
#  '1994',
#  '1994',
#  '1994',
#  '1994',
#  '1994',
#  '1994',
#  '1994',
#  '1994',
#  '1994',
#  '1993',
#  '1993',
#  '1993',
#  '1993',
#  '1993',
#  '1993',
#  '1993',
#  '1993',
#  '1993',
#  '1993',
#  '1993',
#  '1993',
#  '1992',
#  '1992',
#  '1992',
#  '1992',
#  '1992',
#  '1992',
#  '1992',
#  '1992',
#  '1992',
#  '1992',
#  '1992',
#  '1992',
#  '1992',
#  '1992',
#  '1992',
#  '1991',
#  '1991',
#  '1991',
#  '1991',
#  '1991',
#  '1991',
#  '1991',
#  '1991',
#  '1991',
#  '1991',
#  '1991',
#  '1991',
#  '1991',
#  '1990',
#  '1990',
#  '1990',
#  '1990',
#  '1990',
#  '1990',
#  '1990',
#  '1990',
#  '1990',
#  '1990',
#  '1990',
#  '1990',
#  '1990',
#  '1990',
#  '1989',
#  '1989',
#  '1989',
#  '1989',
#  '1989',
#  '1989',
#  '1989',
#  '1989',
#  '1989',
#  '1989',
#  '1989',
#  '1989',
#  '1989',
#  '1989',
#  '1989',
#  '1988',
#  '1988',
#  '1988',
#  '1988',
#  '1988',
#  '1988',
#  '1988',
#  '1988',
#  '1988',
#  '1988',
#  '1988',
#  '1988',
#  '1988',
#  '1988',
#  '1988',
#  '1988',
#  '1987',
#  '1987',
#  '1987',
#  '1987',
#  '1987',
#  '1987',
#  '1987',
#  '1987',
#  '1987',
#  '1987',
#  '1987',
#  '1987',
#  '1987',
#  '1986',
#  '1986',
#  '1986',
#  '1986',
#  '1986',
#  '1986',
#  '1986',
#  '1986',
#  '1986',
#  '1986',
#  '1986',
#  '1986',
#  '1986',
#  '1986',
#  '1986',
#  '1986',
#  '1985',
#  '1985',
#  '1985',
#  '1985',
#  '1985',
#  '1985',
#  '1985',
#  '1985',
#  '1985',
#  '1985',
#  '1985',
#  '1985',
#  '1985',
#  '1985',
#  '1985',
#  '1984',
#  '1984',
#  '1984',
#  '1984',
#  '1984',
#  '1984',
#  '1984',
#  '1984',
#  '1984',
#  '1984',
#  '1984',
#  '1984',
#  '1984',
#  '1983',
#  '1983',
#  '1983',
#  '1983',
#  '1983',
#  '1983',
#  '1983',
#  '1983',
#  '1983',
#  '1983',
#  '1983',
#  '1983',
#  '1982',
#  '1982',
#  '1982',
#  '1982',
#  '1982',
#  '1982',
#  '1982',
#  '1982',
#  '1982',
#  '1982',
#  '1982',
#  '1982',
#  '1982',
#  '1981',
#  '1981',
#  '1981',
#  '1981',
#  '1981',
#  '1981',
#  '1981',
#  '1981',
#  '1981',
#  '1981',
#  '1981',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1977',
#  '1977',
#  '1977',
#  '1977',
#  '1977',
#  '1977',
#  '1977',
#  '1977',
#  '1977',
#  '1977',
#  '1977',
#  '1977',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1974',
#  '1974',
#  '1974',
#  '1974',
#  '1974',
#  '1974',
#  '1974',
#  '1974',
#  '1974',
#  '1974',
#  '1974',
#  '1974',
#  '1974',
#  '1973',
#  '1973',
#  '1973',
#  '1973',
#  '1973',
#  '1973',
#  '1973',
#  '1973',
#  '1973',
#  '1973',
#  '1973',
#  '1973',
#  '1973',
#  '1972',
#  '1972',
#  '1972',
#  '1972',
#  '1972',
#  '1972',
#  '1972',
#  '1972',
#  '1972',
#  '1972',
#  '1972',
#  '1972',
#  '1971',
#  '1971',
#  '1971',
#  '1971',
#  '1971',
#  '1971',
#  '1971',
#  '1971',
#  '1971',
#  '1971',
#  '1971',
#  '1971',
#  '1971',
#  '1970',
#  '1970',
#  '1970',
#  '1970',
#  '1970',
#  '1970',
#  '1970',
#  '1970',
#  '1970',
#  '1970',
#  '1970',
#  '1970',
#  '1970',
#  '1970',
#  '1970',
#  '1969',
#  '1969',
#  '1969',
#  '1969',
#  '1969',
#  '1969',
#  '1969',
#  '1969',
#  '1969',
#  '1969',
#  '1969',
#  '1969',
#  '1969',
#  '1969',
#  '1968',
#  '1968',
#  '1968',
#  '1968',
#  '1968',
#  '1968',
#  '1967',
#  '1968',
#  '1968',
#  '1968',
#  '1968',
#  '1968',
#  '1968',
#  '1968',
#  '1968',
#  '1968',
#  '1968',
#  '1967',
#  '1967',
#  '1967',
#  '1967',
#  '1967',
#  '1967',
#  '1967',
#  '1967',
#  '1967',
#  '1967',
#  '1967',
#  '1967',
#  '1967',
#  '1967',
#  '1966',
#  '1966',
#  '1966',
#  '1966',
#  '1966',
#  '1966',
#  '1966',
#  '1966',
#  '1966',
#  '1966',
#  '1966',
#  '1966',
#  '1965',
#  '1965',
#  '1965',
#  '1965',
#  '1965',
#  '1965',
#  '1965',
#  '1965',
#  '1965',
#  '1965',
#  '1965',
#  '1965',
#  '1964',
#  '28',
#  '1954',
#  '1949',
#  '1938',
#  '1951',
#  '1943',
#  '1960',
#  '1953',
#  '1957',
#  '1938',
#  '1950',
#  '30',
#  '1941',
#  '1949',
#  '1958',
#  '1963',
#  '1951',
#  '1943',
#  '1956',
#  '1945',
#  '1946',
#  '1950',
#  '1936',
#  '1960',
#  '1949',
#  '1940',
#  '1956',
#  '1937',
#  '1947',
#  '1952',
#  '32',
#  '1954',
#  '1942',
#  '1949',
#  '1953',
#  '1964',
#  '1945',
#  '1959',
#  '1951',
#  '1956',
#  '1946',
#  '1942',
#  '1949',
#  '1938',
#  '1958',
#  '30',
#  '1948',
#  '1957',
#  '1947',
#  '1962',
#  '1947',
#  '1959',
#  '1942',
#  '1946',
#  '1941',
#  '1945',
#  '1941',
#  '1947',
#  '1936',
#  '1950',
#  '1946',
#  '1938',
#  '1956',
#  '1961',
#  '1952',
#  '29',
#  '1957',
#  '1955',
#  '1935',
#  '29',
#  '1954',
#  '1939',
#  '1960',
#  '1953',
#  '1953',
#  '1950',
#  '1937',
#  '1943',
#  '1964',
#  '1946',
#  '33',
#  '1963',
#  '32',
#  '1949',
#  '1949',
#  '1936',
#  '1965',
#  '1941',
#  '31',
#  '28',
#  '1941',
#  '1934',
#  '1934',
#  '1963',
#  '1947',
#  '1936',
#  '1952',
#  '29',
#  '1936',
#  '1954',
#  '1944',
#  '1938',
#  '1943',
#  '1956',
#  '1963',
#  '1934',
#  '1950',
#  '1937',
#  '1935',
#  '1935',
#  '31',
#  '1960',
#  '1949',
#  '1962',
#  '1943',
#  '1938',
#  '1958',
#  '1942',
#  '1943',
#  '1947',
#  '1957',
#  '1950',
#  '1959',
#  '30',
#  '29',
#  '1962',
#  '30',
#  '1936',
#  '1965',
#  '1947',
#  '28',
#  '32',
#  '1941',
#  '1962',
#  '1955',
#  '1948',
#  '1960',
#  '1957',
#  '1934',
#  '1960',
#  '1955',
#  '1946',
#  '1960',
#  '1940',
#  '33',
#  '1947',
#  '1964',
#  '1963',
#  '1938',
#  '1944',
#  '1947',
#  '32',
#  '1935',
#  '1949',
#  '1943',
#  '1952',
#  '1961',
#  '31',
#  '1945',
#  '1953',
#  '1936',
#  '1944',
#  '1954',
#  '1934',
#  '1947',
#  '1950',
#  '1956',
#  '1958',
#  '1960',
#  '1936',
#  '1959',
#  '1954',
#  '1944',
#  '1935',
#  '1959',
#  '1964',
#  '1939',
#  '1937',
#  '1947',
#  '1939',
#  '1958',
#  '32',
#  ...]

# %%
len(Film)
# Out:
# 1363

# %%
len(Year)
# Out:
# 1363

# %%
len(Award)
# Out:
# 1362

# %%
len(Nomination)
# Out:
# 1362

# %%
Film[-4]
# Out:
# 'Zorba the Greek'

# %%
Film[:1359]
# Out:
# 'Zorba the Greek'

# %%
 oscar = pd.DataFrame({"Films": Film[:1360], "Year": Year[:1360], "Awards": Award[:1360], "Nomination": Nomination[:1360]})

# %%
oscar
# Out:
#                                   Films  Year Awards Nomination
# 0     Everything Everywhere All at Once  2022      7       11\n
# 1        All Quiet on the Western Front  2022      4        9\n
# 2                             The Whale  2022      2        3\n
# 3                     Top Gun: Maverick  2022      1        6\n
# 4        Black Panther: Wakanda Forever  2022      1        5\n
# ...                                 ...   ...    ...        ...
# 1355            The Yankee Doodle Mouse  1943      1        1\n
# 1356                       The Yearling  1946      2        7\n
# 1357      Yesterday, Today and Tomorrow  1964      1        1\n
# 1358         You Can't Take It with You  1938      2        7\n
# 1359                    Zorba the Greek  1964      3        7\n
#
# [1360 rows x 4 columns]

# %%
oscar.to_csv("scraped data about movies")

# %%
oscar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1360 entries, 0 to 1359
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Films       1360 non-null   object
#  1   Year        1360 non-null   object
#  2   Awards      1360 non-null   object
#  3   Nomination  1360 non-null   object
# dtypes: object(4)
# memory usage: 42.6+ KB

# %%
oscar.Year = oscar.Year.astype(int)

# %%
oscar.Awards = oscar.Awards.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-c50f3533e5a3> in <cell line: 1>()
# ----> 1 oscar.Awards = oscar.Awards.astype(int)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     350                     applied = b.apply(f, **kwargs)
#     351                 else:
# --> 352                     applied = getattr(b, f)(**kwargs)
#     353             except (TypeError, NotImplementedError):
#     354                 if not ignore_failures:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     524         values = self.values
#     525
# --> 526         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     527
#     528         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array_safe(values, dtype, copy, errors)
#     297
#     298     try:
# --> 299         new_values = astype_array(values, dtype, copy=copy)
#     300     except (ValueError, TypeError):
#     301         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     228
#     229     else:
# --> 230         values = astype_nansafe(values, dtype, copy=copy)
#     231
#     232     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_nansafe(arr, dtype, copy, skipna)
#     168     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169         # Explicit copy, or required since NumPy can't view from / to object.
# --> 170         return arr.astype(dtype, copy=True)
#     171
#     172     return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '[1]'

# %%
oscar.Nomination = oscar.Nomination.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-fca832008f5a> in <cell line: 1>()
# ----> 1 oscar.Nomination = oscar.Nomination.astype(int)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     350                     applied = b.apply(f, **kwargs)
#     351                 else:
# --> 352                     applied = getattr(b, f)(**kwargs)
#     353             except (TypeError, NotImplementedError):
#     354                 if not ignore_failures:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     524         values = self.values
#     525
# --> 526         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     527
#     528         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array_safe(values, dtype, copy, errors)
#     297
#     298     try:
# --> 299         new_values = astype_array(values, dtype, copy=copy)
#     300     except (ValueError, TypeError):
#     301         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     228
#     229     else:
# --> 230         values = astype_nansafe(values, dtype, copy=copy)
#     231
#     232     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_nansafe(arr, dtype, copy, skipna)
#     168     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169         # Explicit copy, or required since NumPy can't view from / to object.
# --> 170         return arr.astype(dtype, copy=True)
#     171
#     172     return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '[2]\n'
